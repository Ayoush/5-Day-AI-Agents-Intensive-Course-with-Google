# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# Load .env file from the same directory as this notebook
# In Jupyter, the current working directory is typically where the notebook is located
try:
    env_file = Path('.env')
    if env_file.exists():
        load_dotenv(dotenv_path=env_file, override=True)
        google_api_key = os.getenv("GOOGLE_API_KEY")
        if not google_api_key:
            raise ValueError("GOOGLE_API_KEY not found in .env file")
        print(f"✅ Gemini API key loaded from .env file (first 10 chars: {google_api_key[:10]}...)")
        print(f"✅ Verified: GOOGLE_API_KEY is set in environment (length: {len(google_api_key)} chars)")
        print("ℹ️  ADK will use GOOGLE_API_KEY")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your .env file. Details: {e}")
# Out:
# ✅ Gemini API key loaded from .env file (first 10 chars: AIzaSyCxBj...)
# ✅ Verified: GOOGLE_API_KEY is set in environment (length: 39 chars)
# ℹ️  ADK will use GOOGLE_API_KEY

# %%
from google.adk.agents import Agent
from google.adk.tools import google_search

root_agent = Agent(
    name="google_search_agent",
    model="gemini-2.5-flash",
    instruction="Answer questions using Google Search when needed. Always cite sources.",
    description="Professional search assistant with Google Search capabilities",
    tools=[google_search]
)

# %%
import requests
from google.genai import types
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search, AgentTool, ToolContext
from google.adk.code_executors import BuiltInCodeExecutor

print("Google ADK tools imported successfully")
# Out:
# Google ADK tools imported successfully

# %%
university_runner = InMemoryRunner(agent=root_agent)
_ = await university_runner.run_debug(
    "I want you to search AIT Pune and give me the information about the university its affiliated to?"
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
#  ### Created new session: debug_session_id
#
# User > I want you to search AIT Pune and give me the information about the university its affiliated to?
# google_search_agent > The Army Institute of Technology (AIT) Pune is affiliated with Savitribai Phule Pune University (SPPU). It is an undergraduate engineering college located in Pune, Maharashtra, India.
#
# AIT Pune is a private institute established in 1994, operating under the aegis of the Army Welfare Education Society (AWES). The institute is recognized by the All India Council for Technical Education (AICTE) and has been accredited by NAAC with an 'A' grade. Only wards of army personnel are admitted to this institute.
